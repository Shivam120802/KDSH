# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/tbhdgfxj/answers3.csv
# /kaggle/input/file1gnhf/sample_submission.csv
# /kaggle/input/file1gnhf/KDAG Hackathon 2022-23 - Problem Statement.pdf
# /kaggle/input/file1gnhf/HCP_Data_KDAG_Hackathon/HCP_Data_KDAG_Hackathon.xlsx
# /kaggle/input/file1gnhf/Patient_Data_KDAG_Hackathon/Patient_Data_KDAG_Hackathon.xlsx

# %%
df_hcp=pd.read_excel('/kaggle/input/file1gnhf/HCP_Data_KDAG_Hackathon/HCP_Data_KDAG_Hackathon.xlsx')
df_pat=pd.read_excel('/kaggle/input/file1gnhf/Patient_Data_KDAG_Hackathon/Patient_Data_KDAG_Hackathon.xlsx')

# %%
df_hcp

# %%
df_hcp['Time_Period']=df_hcp['Time_Period'].apply(lambda x:str(x))

# %%
df_hcp['Time_Period']=pd.to_datetime(df_hcp['Time_Period'])

# %%
type(df_hcp['Time_Period'][1])

# %%
df_hcp=df_hcp.set_index('Time_Period')

# %%
df_hcp.corr()

# %%
df_pat=df_pat.set_index('Date_of_Visit')

# %%
df_pat[df_pat['Physician_ID']=='axt00001']

# %%
df_hcp

# %%
num_of_pat=df_pat.groupby('Physician_ID').resample('W').size().rename("nums").reset_index()

# %%
num_of_pat

# %%
df_hcp_final=df_hcp.merge(num_of_pat,how='outer')

# %%
df_hcp_final

# %%
df_pat[df_pat['Physician_ID']=='axt00001']

# %%
df_hcp[df_hcp['Physician_ID']=='axt00001']

# %%
df_hcp_final.corr()

# %%
df_hcp_final.isnull().sum()

# %%
df_hcp_final=df_hcp_final.fillna(0)

# %%
df_hcp_final.isnull().sum()

# %%
df_hcp_final[df_hcp_final['nums']!=0]

# %%
df_pat

# %%
df_hcp_final.corr()

# %%
df_hcp_final

# %%
df_hcp_final_new=df_hcp_final.drop(['Date_of_Visit','Specialty'],axis=1)

# %%
def checking(var):
    if var==0:
        return 0
    else:
        return 1

# %%
df_hcp_final_new['Email_done']=df_hcp_final_new['Emails_Delivered'].apply(checking)

# %%
df_hcp_final_new['Sample_done']=df_hcp_final_new['Samples_Dropped'].apply(checking)

# %%
df_hcp_final_new

# %%
df_hcp_final_new.corr()

# %%
df_hcp_final_new.describe()

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6,12),dpi=150)
sns.boxplot(y='Brand_Rx',data=df_hcp_final_new,x='Email_done')

# %%
def rating(var):
    if var>1:
        return 'good'
    else:
        return 'bad'

# %%
df_hcp_final_new['quality']=df_hcp_final_new['Brand_Rx'].apply(rating)

# %%
df_hcp_final_new['quality'].value_counts()

# %%
df_hcp_final_new=df_hcp_final_new.drop('Physician_ID',axis=1)

# %%
df_hcp_final_new

# %%
df_hcp_final_new=pd.get_dummies(df_hcp_final_new)

# %%
df_hcp_final_new

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
df_hcp_final_new=scaler.fit_transform(df_hcp_final_new)

# %%
from sklearn.cluster import KMeans

# %%
model=KMeans(n_clusters=3)

# %%
cluster_labels=model.fit_predict(df_hcp_final_new)

# %%
cluster_labels

# %%
df_hcp_final['Cluster']=cluster_labels

# %%
df_hcp_final.corr()

# %%
df_hcp_final[df_hcp_final['Physician_ID'].isin(df_hcp['Physician_ID'])]['Physician_ID'].nunique()

# %%
df_hcp_final.isnull().sum()

# %%
df_hcp_final['Cluster'].value_counts()

# %%
model.cluster_centers_

# %%
df_hcp_final_new

# %%
df_hcp_final[df_hcp_final['Physician_ID']=='axt00001']['Cluster'].value_counts()

# %%
results=df_hcp_final.groupby('Physician_ID')['Cluster'].agg(pd.Series.mode)

# %%
results

# %%
results

# %%
len(results)

# %%
names=df_hcp['Physician_ID'].unique()

# %%
final_results=pd.DataFrame(data=results)

# %%
final_results.columns=['Channel']

# %%
final_results

# %%
final_results.to_csv('answers5')

# %%
final_results

# %%
df_hcp_final

# %%
X=df_hcp_final['Cluster']

# %%
df_results=pd.read_csv('/kaggle/input/tbhdgfxj/answers3.csv')

# %%
df_results

# %%
y=df_hcp_final['Brand_Rx']

# %%
from sklearn.model_selection import train_test_split

# %%
X=X.values.reshape(-1,1)

# %%
y=y.values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=9,include_bias=False)

# %%
poly_X=poly.fit_transform(X)

# %%
polyX_train, polyX_test, polyy_train, polyy_test = train_test_split(poly_X, y, test_size=0.25, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_model2=LinearRegression()

# %%
lin_model2.fit(polyX_train,polyy_train)

# %%
poly_test_predictions=lin_model2.predict(polyX_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
poly_MAE = mean_absolute_error(y_test,poly_test_predictions)
poly_MSE = mean_squared_error(y_test,poly_test_predictions)
poly_RMSE = np.sqrt(poly_MSE)

# %%
poly_MAE

# %%
poly_RMSE

# %%
lin_model.fit(X,y)

# %%
lin_model2.fit(poly_X,y)

# %%
X_results=df_results['Channel']

# %%
X_results=X_results.values.reshape(-1,1)

# %%
poly_X_results=poly.fit_transform(X_results)

# %%
final_reg_results=lin_model2.predict(poly_X_results)

# %%
len(final_reg_results)

# %%
reg_results=pd.DataFrame(index=df_results['Physician_ID'],data=final_reg_results)

# %%
reg_results.columns=['Expected_TRx']

# %%
reg_results.to_csv('reg_results')
